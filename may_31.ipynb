# %%
import pandas as pd
import numpy as np

# %%
li=pd.read_excel("ilearn_access_log.xlsx")
li
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
df=pd.DataFrame(li)
df
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
index_names=df[df['path']=='/'].index
df.drop(index_names,inplace=True)
df
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 7     119     Shruti       NaN 2018-02-09 12:37:00
# 8     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
file=open("log_rejeted.txt",'a')
file.write(str(df))
# Out:
# 1609

# %%
employee=df[['id','first_name','last_name']].drop_duplicates()
employee
# Out:
#        id    first_name   last_name
# 1     119        Shruti         NaN
# 61    136        Shilpa           m
# 68    152        Ramesh         NaN
# 147   158      Sinchana         NaN
# 164   159        Irshad         NaN
# 177   229         Geeta           M
# 314   245       Sasmita     Routary
# 346   253         Pooja     Baadkar
# 379   267        Akshay           G
# 385   269      Prasanna   Pattankar
# 408   290       Shruthi           S
# 442   301        Sachin       Kumar
# 710   306        Soumya       Shree
# 823   308         jyoti           n
# 901   310         anita       reddy
# 935   312   rajashekhar           S
# 1060  314       Mustafa          SM
# 1172  317        aditya           j
# 1177  320        Subhra           P
# 1192  325         Ramya           b
# 1315  326    sengamalai           P
# 1408  332      Mahadeva       Swamy
# 1427  342       Supriya           K
# 1517  353        Prerna        Purn
# 1610  354        Dhiraj       Kumar
# ...

# %%
df=employee.set_index('id')
df
# Out:
#        first_name   last_name
# id
# 119        Shruti         NaN
# 136        Shilpa           m
# 152        Ramesh         NaN
# 158      Sinchana         NaN
# 159        Irshad         NaN
# 229         Geeta           M
# 245       Sasmita     Routary
# 253         Pooja     Baadkar
# 267        Akshay           G
# 269      Prasanna   Pattankar
# 290       Shruthi           S
# 301        Sachin       Kumar
# 306        Soumya       Shree
# 308         jyoti           n
# 310         anita       reddy
# 312   rajashekhar           S
# 314       Mustafa          SM
# 317        aditya           j
# 320        Subhra           P
# 325         Ramya           b
# 326    sengamalai           P
# 332      Mahadeva       Swamy
# 342       Supriya           K
# 353        Prerna        Purn
# 354        Dhiraj       Kumar
# 355       Pramodh      Munnar
# 359        Nithya  Srinivasan
# 360       Kavitha       Nayak
# 362     Niveditha    Kulkarni
# 363         Sapna           S
# ...

# %%
df.to_excel("employee.xlsx")
df
# Out:
#        first_name   last_name
# id
# 119        Shruti         NaN
# 136        Shilpa           m
# 152        Ramesh         NaN
# 158      Sinchana         NaN
# 159        Irshad         NaN
# 229         Geeta           M
# 245       Sasmita     Routary
# 253         Pooja     Baadkar
# 267        Akshay           G
# 269      Prasanna   Pattankar
# 290       Shruthi           S
# 301        Sachin       Kumar
# 306        Soumya       Shree
# 308         jyoti           n
# 310         anita       reddy
# 312   rajashekhar           S
# 314       Mustafa          SM
# 317        aditya           j
# 320        Subhra           P
# 325         Ramya           b
# 326    sengamalai           P
# 332      Mahadeva       Swamy
# 342       Supriya           K
# 353        Prerna        Purn
# 354        Dhiraj       Kumar
# 355       Pramodh      Munnar
# 359        Nithya  Srinivasan
# 360       Kavitha       Nayak
# 362     Niveditha    Kulkarni
# 363         Sapna           S
# ...

# %%
df1=df['path'].str.split('/',expand=True)
df1
# Out:
#      0         1             2                                    3     4
# 1        courses    oracle-sql   introduction-to-sql-oracle-sql-102
# 2        courses   informatica  rank-transforamtion-informatica-405
# 6        courses    oracle-sql   introduction-to-sql-oracle-sql-102
# 7        courses    oracle-sql                                       None
# 8        courses  oracle-plsql                                       None
# ...  ..      ...           ...                                  ...   ...
# 2157     courses         rdbms                  ef-codds-rules-file
# 2158     courses         rdbms                  ef-codds-rules-file
# 2159     courses         rdbms                                       None
# 2160     courses         rdbms  what-is-a-transaction-file-rdbms-40
# 2161     courses         rdbms  what-is-a-transaction-file-rdbms-40
#
# [1740 rows x 5 columns]

# %%
df1=df.copy()
df1[['c_id','cource','cource_name','chapter_name','with_out_chapter_name']]=df1['path'].str.split('/',expand=True)
df1
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 7     119     Shruti       NaN 2018-02-09 12:37:00
# 8     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp  \
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
df
# Out:
#        id first_name last_name          last_login  \
# 0     119     Shruti       NaN 2018-02-09 12:37:00
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 3     119     Shruti       NaN 2018-02-09 12:37:00
# 4     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp
# 0                                                     / 2017-10-06 09:09:00
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# ...

# %%
df1.drop('with_out_chapter_name',axis=1,inplace=True)
df1
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 7     119     Shruti       NaN 2018-02-09 12:37:00
# 8     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp  \
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
df1.drop('c_id',axis=1,inplace=True)
df1
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 7     119     Shruti       NaN 2018-02-09 12:37:00
# 8     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp  \
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
df3=df1.copy()
df3=df3.replace(r'^s*$',float('NaN'),regex=True)
df3
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 7     119     Shruti       NaN 2018-02-09 12:37:00
# 8     119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2159  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp  \
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
df4=df3[df3.chapter_name.notnull()]
df4
# Out:
#        id first_name last_name          last_login  \
# 1     119     Shruti       NaN 2018-02-09 12:37:00
# 2     119     Shruti       NaN 2018-02-09 12:37:00
# 6     119     Shruti       NaN 2018-02-09 12:37:00
# 19    119     Shruti       NaN 2018-02-09 12:37:00
# 20    119     Shruti       NaN 2018-02-09 12:37:00
# ...   ...        ...       ...                 ...
# 2155  386     Swarup         S 2018-05-27 15:59:00
# 2157  386     Swarup         S 2018-05-27 15:59:00
# 2158  386     Swarup         S 2018-05-27 15:59:00
# 2160  386     Swarup         S 2018-05-27 15:59:00
# 2161  386     Swarup         S 2018-05-27 15:59:00
#
#                                                    path           timestamp  \
# 1     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-06 09:09:00
# 2     /courses/informatica/rank-transforamtion-infor... 2017-10-06 09:09:00
# 6     /courses/oracle-sql/introduction-to-sql-oracle... 2017-10-10 07:03:00
# ...

# %%
# df2=df1.copy()
# index_names=df2[df2['chapter_name']==NaN].index
# df2.drop(index_names,inplace=True)
# df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-99c6853301d1> in <module>
#       1 df2=df1.copy()
# ----> 2 index_names=df2[df2['chapter_name']==NaN].index
#       3 df2.drop(index_names,inplace=True)
#       4 df2
#
# NameError: name 'NaN' is not defined

# %%
df5=df4[['id','timestamp','cource_name','chapter_name',]]
df5
# Out:
#        id           timestamp  cource_name  \
# 1     119 2017-10-06 09:09:00   oracle-sql
# 2     119 2017-10-06 09:09:00  informatica
# 6     119 2017-10-10 07:03:00   oracle-sql
# 19    119 2017-10-17 08:48:00  informatica
# 20    119 2017-10-17 08:48:00  informatica
# ...   ...                 ...          ...
# 2155  386 2018-05-27 16:14:00        rdbms
# 2157  386 2018-05-27 16:27:00        rdbms
# 2158  386 2018-05-27 16:27:00        rdbms
# 2160  386 2018-05-27 17:00:00        rdbms
# 2161  386 2018-05-27 17:00:00        rdbms
#
#                                      chapter_name
# 1              introduction-to-sql-oracle-sql-102
# 2             rank-transforamtion-informatica-405
# 6              introduction-to-sql-oracle-sql-102
# 19    introduction-to-informatica-informatica-392
# 20             working-with-files-informatica-394
# ...                                           ...
# 2155        primary-key-foreign-key-file-rdbms-38
# ...

# %%
df = pd.DataFrame(np.random.randint(1,100,size=(11, 3)), columns=list('ABC'))
df
# Out:
#      A   B   C
# 0   25  12  19
# 1   86  65  16
# 2   40  84  96
# 3   92  61  36
# 4   17  97  15
# 5   29  96  85
# 6   71  27  29
# 7   35  67  92
# 8   74  65  20
# 9   11  13  54
# 10  30  45  94

# %%
df.set_index('A')
# Out:
#      B   C
# A
# 5   97  84
# 21  73  99
# 84  11  34
# 87  50   8
# 14  58  62
# 69  58  72
# 25   7  43
# 10  96  97
# 38  26  25
# 47  51  27
# 90   1  41

# %%
df = pd.DataFrame(np.random.randint(1,100,size=11), columns=list('access_id'))
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\Anaconda\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_blocks(blocks, axes)
#    1674                 blocks = [
# -> 1675                     make_block(
#    1676                         values=blocks[0], placement=slice(0, len(axes[0])), ndim=2
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2741
# -> 2742     return klass(values, ndim=ndim, placement=placement)
#    2743
#
# E:\Anaconda\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#
# ...
